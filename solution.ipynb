# %% [markdown]
# Sure. I’ll do two things:
#
# 1. **Turn the “one RHP zero + two poles” result into a Bode-plot story** (magnitude + phase, step-by-step).
# 2. **Explain the units and physics of** $$( \omega_z = \dfrac{g_m}{C_{gd}} )$$ and why dividing those two gives an angular frequency.
#
# 1) **Start from the canonical transfer function form**
# $\omega_z = \dfrac{g_m}{C_{gd}}$
# For a common-source stage with a feedforward capacitor $( C_{gd} )$, you typically end up with:

# %% [markdown]
# git add .
# git commit -m "Your message here"
# git push origin main
